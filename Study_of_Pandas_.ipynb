# %% [markdown]
# <a href="https://colab.research.google.com/github/falakj07/Pandas/blob/main/Study_of_Pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 9
# ## Name - Falak Jain
# ## PRN - 25070123047
# ## Batch ENTC A3
# ## Study of Pandas

# %%
# Introduction to Pandas
#Pandas:Panel data
#Structured Data
# Data cleaning

# %%
import pandas as pd
s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Create DataFrame
data = {
    "Name":["GEETALI","VANSHIKA","MIHIKA"],
    "Marks":[85,90,78]
}
df = pd.DataFrame(data)
df
# Out:
#        Name  Marks
# 0   GEETALI     85
# 1  VANSHIKA     90
# 2    MIHIKA     78

# %%
## FIND THE STRUCUTRE OF DATAFRAME
df.shape
# Out:
# (3, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (3, 2)

# %%
df.size
# Out:
# 6

# %%
# Display Column Names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
# Check Data types of each column
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
## Access individual Column
df["Name"]
# Out:
# 0     GEETALI
# 1    VANSHIKA
# 2      MIHIKA
# Name: Name, dtype: object

# %%
df["Marks"]
# Out:
# 0    85
# 1    90
# 2    78
# Name: Marks, dtype: int64

# %%
#Access Specific Rows
df.loc[2]
# Out:
# Name     MIHIKA
# Marks        78
# Name: 2, dtype: object

# %%
# Add a new column
'''if marks 89-90-First class
If marks>90- Distinction
If marks > 80-90 Second class'''

df["Grade"] = ["First Class ", "Distinction ","Second Class "]
df
# Out:
#        Name  Marks          Grade
# 0   GEETALI     85   First Class
# 1  VANSHIKA     90   Distinction
# 2    MIHIKA     78  Second Class

# %%
## # Update the Data in DataFrame
# Change marks of student from Geetali to 88

df.loc[0,"Marks"] = 88
df
# Out:
#        Name  Marks          Grade
# 0   GEETALI     88   First Class
# 1  VANSHIKA     90   Distinction
# 2    MIHIKA     78  Second Class

# %%
# Delete any column
df.drop("Grade", axis=1,inplace=True) # TRUE - changes only temporily
df
# Out:
#        Name  Marks
# 0   GEETALI     88
# 1  VANSHIKA     90
# 2    MIHIKA     78

# %%
# Perform basic Statistical Analysis
mean1 =df["Marks"].mean()
mean1
# Out:
# np.float64(85.33333333333333)

# %%
mode1 =df["Marks"].mode()
mode1
# Out:
# 0    78
# 1    88
# 2    90
# Name: Marks, dtype: int64

# %%
min1=df["Marks"].min()
min1
# Out:
# 78

# %%
max1=df["Marks"].max()
max1
# Out:
# 90

# %%
# Apply condition ( Filtering)
# Display students scoring more than 80
df[df["Marks"] > 80]
# Out:
#        Name  Marks
# 0   GEETALI     88
# 1  VANSHIKA     90

# %%
import pandas as pd
import numpy as np
df1=pd.DataFrame({'C1':[11,21,np.nan] , 'C2':[15,np.nan,np.nan],'C3':[10,29,30]})
df1
# Out:
#      C1    C2  C3
# 0  11.0  15.0  10
# 1  21.0   NaN  29
# 2   NaN   NaN  30

# %%
df1.isna () # Boolean function
# Out:
#       C1     C2     C3
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df1.notna ()
# Out:
#       C1     C2    C3
# 0   True   True  True
# 1   True  False  True
# 2  False  False  True

# %%
df1.isna().sum() # columnwise na values
# Out:
# C1    1
# C2    2
# C3    0
# dtype: int64

# %%
df1.dropna() # nAN ROWS ARE DROPPED
# Out:
#      C1    C2  C3
# 0  11.0  15.0  10
